# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jait-mukkamalla/flyrank-internship-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# ***Classification, clustering, ranking, or scoring — which one, and why?***
#
# My lane, lane #2, breaks down into multiple tasks, each serving its own purpose. We will build a scoring model that will rank the pages that are most susceptible to decline. These pages can then be passed to a multi-label classification model that determines what fixes, one or multiple, each page needs. We will need to do some exploratory data analysis to determine what features from the data are associated with each type of fix.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# ***What would you predict? Where does that label come from — observed outcome or a defined rule?***
#
# For the scoring model, the goal is predict a proxy label that represents the % decrease in impressions and CTR for a page between 2 ten week periods: pre-cutoff and post-cutoff. We will use historical data to train the model because we already know the outcome, thus the model can learn the patterns through observation rather than a human rule.
#
# For the multi-label classification model, the goal is to predict for each fix-type, whether a fix was applied at a cutoff AND was followed by a % increase in the relevant metric(s) over the 10 weeks after vs. before (five separate labels). We need to combine the usage of the cutoff idea from the scoring model and combine it with a filter to ensure the metric(s) increases for that fix type to ensure the model learns the correct time to apply fixes from the actual data, rather than human rules/labels.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
